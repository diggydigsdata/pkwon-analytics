# %%
import pandas as pd
import glob
import os
import shutil

# %%
code_to_country = {
    'ENG': 'England',
    'ITA': 'Italy',
    'FRA': 'France',
    'SUI': 'Switzerland',
    'NGA': 'Nigeria',
    'CIV': 'Ivory Coast',
    'ESP': 'Spain',
    'ARG': 'Argentina',
    'SWE': 'Sweden',
    'BRA': 'Brazil',
    'ALG': 'Algeria',
    'AUT': 'Austria',
    'ALB': 'Albania',
    'IDN': 'Indonesia',
    'GER': 'Germany',
    'IRN': 'Iran',
    'MAR': 'Morocco',
    'CRO': 'Croatia',
    'URU': 'Uruguay',
    'NED': 'Netherlands',
    'ZAM': 'Zambia',
    'POR': 'Portugal',
    'CZE': 'Czech Republic',
    'POL': 'Poland',
    'DEN': 'Denmark',
    'GNB': 'Guinea-Bissau',
    'SVN': 'Slovenia',
    'MLI': 'Mali',
    'NOR': 'Norway',
    'ROU': 'Romania',
    'TUN': 'Tunisia',
    'CAN': 'Canada',
    'CPV': 'Cape Verde',
    'NZL': 'New Zealand',
    'TUR': 'Turkey',
    'SEN': 'Senegal',
    'COL': 'Colombia',
    'BEL': 'Belgium',
    'MTQ': 'Martinique',
    'SCO': 'Scotland',
    'SVK': 'Slovakia',
    'GHA': 'Ghana',
    'IRL': 'Republic of Ireland',
    'CMR': 'Cameroon',
    'MKD': 'North Macedonia',
    'CHI': 'Chile',
    'LTU': 'Lithuania',
    'ISL': 'Iceland',
    'SUR': 'Suriname',
    'GRE': 'Greece',
    'SRB': 'Serbia',
    'SLE': 'Sierra Leone',
    'JPN': 'Japan',
    'CYP': 'Cyprus',
    'BIH': 'Bosnia and Herzegovina',
    'UKR': 'Ukraine',
    'MNE': 'Montenegro',
    'GEO': 'Georgia',
    'PER': 'Peru',
    'ANG': 'Angola',
    'CGO': 'Republic of the Congo',
    'USA': 'United States',
    'RUS': 'Russia',
    'ARM': 'Armenia',
    'EQG': 'Equatorial Guinea',
    'MEX': 'Mexico',
    'GAB': 'Gabon',
    'KVX': 'Kosovo',
    'PAR': 'Paraguay',
    'UZB': 'Uzbekistan',
    'JAM': 'Jamaica',
    'ISR': 'Israel',
    'ZIM': 'Zimbabwe'
}

# %%
# Step 1: Backup raw data
shutil.copytree("../data/raw", "../data/raw_backup_12_06_25", dirs_exist_ok=True)
print("✅ Backup complete!")
# Out:
# ✅ Backup complete!

# %%
# Step 0: Utility function to clean all column names
def clean_columns(df):
    df.columns = (
        df.columns.str.strip()
                  .str.lower()
                  .str.replace(" ", "_")
                  .str.replace("-", "_")
                  .str.replace(".", "_", regex=False)
    )
    return df

# Step 1: Define the rename map based on cleaned columns
rename_map = {
    "rk": "rank",
    "nation": "nationality",
    "gls_1": "goals_per90",
    "ast_1": "assists_per90",
    "g+a_1": "goals_and_assists_per90",
    "g_pk_1": "non_penalty_goals_per90",
    "g+a_pk": "non_penalty_goals_and_assists_per90",
    "pos": "position",
    "squad": "team",
    "born": "birth_year",
    "min": "minutes",
    "gls": "goals",
    "ast": "assists",
    "pk": "pens_scored",
    "pkatt": "pens_attempted",
    "g+a": "goals_and_assists",
    "g_pk": "non_penalty_goals",
    "g+a_pk": "non_penalty_goals_and_assists",
    "fls": "fouls_committed",
    "fld": "fouls_drawn",
    "mp": "matches_played",
    "off": "offsides",
    "prgc": "progressive_carries",
    "prgr": "progressive_receptions",
    "recov": "ball_recoveries",
    "won": "aerial_duels_won",
    "lost": "aerial_duels_lost",
    "won%": "aerial_duel_win_rate",
    "xag": "xag_expected_assisted_goals",
    "xg": "xg_expected_goals",
    "npxg": "npxg_non_penalty_xg",
    "xa": "xa_expected_assists",
}

# Step 2: Define columns to delete
cols_to_delete = [
    "rank", "matches", "crdy", "crdr", "90s", "pkcon", "og", "int", "tklw", "crs",
    "2crdy", "progressive_receptions", "ball_recoveries",
    "aerial_duels_won", "aerial_duels_lost", "aerial_duel_win_rate", "fouls_committed", "xg_1", "xag_1", "xg+xag", "npxg_1", "npxg+xag_1"
]

# %%
# Step 3: Find all raw CSVs
csv_files = glob.glob("../data/raw/**/*.csv", recursive=True)
print(f"Found {len(csv_files)} raw CSVs.")
# Out:
# Found 106 raw CSVs.

# %%
# Step 4: Clean each file
for idx, file in enumerate(csv_files):
    print(f"Cleaning file {idx+1}/{len(csv_files)}: {file}")

    # Read CSV
    df = pd.read_csv(file)

    # 🧹 CLEAN columns first
    df = clean_columns(df)

    # 🛠 Then RENAME
    df = df.rename(columns=rename_map)

    # 🌍 Fix nationality values
    df['country_code'] = df['nationality'].apply(lambda x: x.split()[-1] if isinstance(x, str) else None)
    df['nationality'] = df['country_code'].map(code_to_country)

    # 🧹 Drop unwanted columns
    df = df.drop(columns=[col for col in cols_to_delete if col in df.columns], errors='ignore')

    # 🧹 Drop any remaining unnamed columns
    df = df.drop(columns=[col for col in df.columns if col.startswith("unnamed")], errors='ignore')

    # Save cleaned file
    clean_path = file.replace("raw", "clean")
    print("→ Columns after cleaning:", df.columns.tolist())
    print("→ Sample nationality values:", df['nationality'].unique()[:5] if 'nationality' in df.columns else "N/A")
    print("→ Saving to:", clean_path)
    os.makedirs(os.path.dirname(clean_path), exist_ok=True)
    df.to_csv(clean_path, index=False)

print("✅ All files cleaned and saved into the clean/ folder!")
# Out:
# Cleaning file 1/106: ../data/raw\bundesliga\Bundesliga_2016-2017_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Argentina' 'Albania' 'Germany' 'Austria' 'Spain']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2016-2017_misc.csv
# Cleaning file 2/106: ../data/raw\bundesliga\Bundesliga_2016-2017_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Argentina' 'Albania' 'Germany' 'Austria' 'Spain']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2016-2017_standard.csv
# Cleaning file 3/106: ../data/raw\bundesliga\Bundesliga_2017-2018_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Argentina' 'Albania' 'Germany' 'Brazil' 'Switzerland']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2017-2018_misc.csv
# Cleaning file 4/106: ../data/raw\bundesliga\Bundesliga_2017-2018_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Argentina' 'Albania' 'Germany' 'Brazil' 'Switzerland']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2017-2018_standard.csv
# Cleaning file 5/106: ../data/raw\bundesliga\Bundesliga_2018-2019_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Argentina' 'Albania' 'United States' 'Germany' 'Switzerland']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2018-2019_misc.csv
# Cleaning file 6/106: ../data/raw\bundesliga\Bundesliga_2018-2019_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Argentina' 'Albania' 'United States' 'Germany' 'Switzerland']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2018-2019_standard.csv
# Cleaning file 7/106: ../data/raw\bundesliga\Bundesliga_2019-2020_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Nigeria' 'Argentina' 'Albania' 'United States' 'Armenia']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2019-2020_misc.csv
# Cleaning file 8/106: ../data/raw\bundesliga\Bundesliga_2019-2020_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Nigeria' 'Argentina' 'Albania' 'United States' 'Armenia']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2019-2020_standard.csv
# Cleaning file 9/106: ../data/raw\bundesliga\Bundesliga_2020-2021_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Argentina' 'Albania' 'Germany' 'United States' 'Armenia']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2020-2021_misc.csv
# Cleaning file 10/106: ../data/raw\bundesliga\Bundesliga_2020-2021_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Argentina' 'Albania' 'Germany' 'United States' 'Armenia']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2020-2021_standard.csv
# Cleaning file 11/106: ../data/raw\bundesliga\Bundesliga_2021-2022_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Nigeria' 'Germany' 'United States' 'Armenia' 'Morocco']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2021-2022_misc.csv
# Cleaning file 12/106: ../data/raw\bundesliga\Bundesliga_2021-2022_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Nigeria' 'Germany' 'United States' 'Armenia' 'Morocco']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2021-2022_standard.csv
# Cleaning file 13/106: ../data/raw\bundesliga\Bundesliga_2022-2023_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['United States' 'Armenia' 'Germany' 'Morocco' 'France']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2022-2023_misc.csv
# Cleaning file 14/106: ../data/raw\bundesliga\Bundesliga_2022-2023_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['United States' 'Armenia' 'Germany' 'Morocco' 'France']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2022-2023_standard.csv
# Cleaning file 15/106: ../data/raw\bundesliga\Bundesliga_2023-2024_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['United States' 'Austria' 'Armenia' 'Germany' 'Morocco']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2023-2024_misc.csv
# Cleaning file 16/106: ../data/raw\bundesliga\Bundesliga_2023-2024_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['United States' 'Austria' 'Armenia' 'Germany' 'Morocco']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2023-2024_standard.csv
# Cleaning file 17/106: ../data/raw\bundesliga\Bundesliga_2024-2025_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Austria' 'Germany' 'Morocco' 'England' 'Nigeria']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2024-2025_misc.csv
# Cleaning file 18/106: ../data/raw\bundesliga\Bundesliga_2024-2025_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Austria' 'Germany' 'Morocco' 'England' 'Nigeria']
# → Saving to: ../data/clean\bundesliga\Bundesliga_2024-2025_standard.csv
# Cleaning file 19/106: ../data/raw\epl\EPL_2016-2017_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Netherlands' 'Scotland' 'Ghana' 'Spain' nan]
# → Saving to: ../data/clean\epl\EPL_2016-2017_misc.csv
# Cleaning file 20/106: ../data/raw\epl\EPL_2016-2017_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Netherlands' 'Scotland' 'Ghana' 'Spain' nan]
# → Saving to: ../data/clean\epl\EPL_2016-2017_standard.csv
# Cleaning file 21/106: ../data/raw\epl\EPL_2017-2018_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Netherlands' 'England' 'Scotland' 'Spain' nan]
# → Saving to: ../data/clean\epl\EPL_2017-2018_misc.csv
# Cleaning file 22/106: ../data/raw\epl\EPL_2017-2018_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Netherlands' 'England' 'Scotland' 'Spain' nan]
# → Saving to: ../data/clean\epl\EPL_2017-2018_standard.csv
# Cleaning file 23/106: ../data/raw\epl\EPL_2018-2019_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Netherlands' 'Argentina' 'England' 'Belgium' 'Brazil']
# → Saving to: ../data/clean\epl\EPL_2018-2019_misc.csv
# Cleaning file 24/106: ../data/raw\epl\EPL_2018-2019_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Netherlands' 'Argentina' 'England' 'Belgium' 'Brazil']
# → Saving to: ../data/clean\epl\EPL_2018-2019_standard.csv
# Cleaning file 25/106: ../data/raw\epl\EPL_2019-2020_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Netherlands' 'England' 'Scotland' 'Spain' 'Argentina']
# → Saving to: ../data/clean\epl\EPL_2019-2020_misc.csv
# Cleaning file 26/106: ../data/raw\epl\EPL_2019-2020_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Netherlands' 'England' 'Scotland' 'Spain' 'Argentina']
# → Saving to: ../data/clean\epl\EPL_2019-2020_standard.csv
# Cleaning file 27/106: ../data/raw\epl\EPL_2020-2021_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Netherlands' 'England' 'Scotland' 'Spain' 'Argentina']
# → Saving to: ../data/clean\epl\EPL_2020-2021_misc.csv
# Cleaning file 28/106: ../data/raw\epl\EPL_2020-2021_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Netherlands' 'England' 'Scotland' 'Spain' 'Argentina']
# → Saving to: ../data/clean\epl\EPL_2020-2021_standard.csv
# Cleaning file 29/106: ../data/raw\epl\EPL_2021-2022_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['England' 'Scotland' 'Algeria' 'Norway' 'Netherlands']
# → Saving to: ../data/clean\epl\EPL_2021-2022_misc.csv
# Cleaning file 30/106: ../data/raw\epl\EPL_2021-2022_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['England' 'Scotland' 'Algeria' 'Norway' 'Netherlands']
# → Saving to: ../data/clean\epl\EPL_2021-2022_standard.csv
# Cleaning file 31/106: ../data/raw\epl\EPL_2022-2023_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['United States' 'England' 'Scotland' 'Morocco' 'France']
# → Saving to: ../data/clean\epl\EPL_2022-2023_misc.csv
# Cleaning file 32/106: ../data/raw\epl\EPL_2022-2023_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['United States' 'England' 'Scotland' 'Morocco' 'France']
# → Saving to: ../data/clean\epl\EPL_2022-2023_standard.csv
# Cleaning file 33/106: ../data/raw\epl\EPL_2023-2024_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['England' 'United States' 'Ivory Coast' 'Morocco' nan]
# → Saving to: ../data/clean\epl\EPL_2023-2024_misc.csv
# Cleaning file 34/106: ../data/raw\epl\EPL_2023-2024_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['England' 'United States' 'Ivory Coast' 'Morocco' nan]
# → Saving to: ../data/clean\epl\EPL_2023-2024_standard.csv
# Cleaning file 35/106: ../data/raw\epl\EPL_2024-2025_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['England' 'United States' 'Ivory Coast' 'Nigeria' 'Algeria']
# → Saving to: ../data/clean\epl\EPL_2024-2025_misc.csv
# Cleaning file 36/106: ../data/raw\epl\EPL_2024-2025_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['England' 'United States' 'Ivory Coast' 'Nigeria' 'Algeria']
# → Saving to: ../data/clean\epl\EPL_2024-2025_standard.csv
# Cleaning file 37/106: ../data/raw\laliga\La Liga_2016-2017_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Tunisia' 'Spain' nan 'Algeria' 'Argentina']
# → Saving to: ../data/clean\laliga\La Liga_2016-2017_misc.csv
# Cleaning file 38/106: ../data/raw\laliga\La Liga_2016-2017_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Tunisia' 'Spain' nan 'Algeria' 'Argentina']
# → Saving to: ../data/clean\laliga\La Liga_2016-2017_standard.csv
# Cleaning file 39/106: ../data/raw\laliga\La Liga_2017-2018_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: [nan 'Spain' 'Uruguay' 'Cameroon' 'Argentina']
# → Saving to: ../data/clean\laliga\La Liga_2017-2018_misc.csv
# Cleaning file 40/106: ../data/raw\laliga\La Liga_2017-2018_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: [nan 'Spain' 'Uruguay' 'Cameroon' 'Argentina']
# → Saving to: ../data/clean\laliga\La Liga_2017-2018_standard.csv
# Cleaning file 41/106: ../data/raw\laliga\La Liga_2018-2019_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Spain' 'Peru' 'Equatorial Guinea' 'Argentina' 'Paraguay']
# → Saving to: ../data/clean\laliga\La Liga_2018-2019_misc.csv
# Cleaning file 42/106: ../data/raw\laliga\La Liga_2018-2019_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Spain' 'Peru' 'Equatorial Guinea' 'Argentina' 'Paraguay']
# → Saving to: ../data/clean\laliga\La Liga_2018-2019_standard.csv
# Cleaning file 43/106: ../data/raw\laliga\La Liga_2019-2020_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Spain' 'Ghana' 'France' 'Senegal' 'Portugal']
# → Saving to: ../data/clean\laliga\La Liga_2019-2020_misc.csv
# Cleaning file 44/106: ../data/raw\laliga\La Liga_2019-2020_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Spain' 'Ghana' 'France' 'Senegal' 'Portugal']
# → Saving to: ../data/clean\laliga\La Liga_2019-2020_standard.csv
# Cleaning file 45/106: ../data/raw\laliga\La Liga_2020-2021_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Ghana' 'Argentina' 'Netherlands' 'Spain' 'Equatorial Guinea']
# → Saving to: ../data/clean\laliga\La Liga_2020-2021_misc.csv
# Cleaning file 46/106: ../data/raw\laliga\La Liga_2020-2021_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Ghana' 'Argentina' 'Netherlands' 'Spain' 'Equatorial Guinea']
# → Saving to: ../data/clean\laliga\La Liga_2020-2021_standard.csv
# Cleaning file 47/106: ../data/raw\laliga\La Liga_2021-2022_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Peru' 'Argentina' 'Spain' 'Ghana' 'Equatorial Guinea']
# → Saving to: ../data/clean\laliga\La Liga_2021-2022_misc.csv
# Cleaning file 48/106: ../data/raw\laliga\La Liga_2021-2022_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Peru' 'Argentina' 'Spain' 'Ghana' 'Equatorial Guinea']
# → Saving to: ../data/clean\laliga\La Liga_2021-2022_standard.csv
# Cleaning file 49/106: ../data/raw\laliga\La Liga_2022-2023_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Brazil' 'Spain' 'Argentina' 'Ghana' 'Nigeria']
# → Saving to: ../data/clean\laliga\La Liga_2022-2023_misc.csv
# Cleaning file 50/106: ../data/raw\laliga\La Liga_2022-2023_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Brazil' 'Spain' 'Argentina' 'Ghana' 'Nigeria']
# → Saving to: ../data/clean\laliga\La Liga_2022-2023_standard.csv
# Cleaning file 51/106: ../data/raw\laliga\La Liga_2023-2024_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['France' 'Brazil' 'Morocco' 'Argentina' 'Spain']
# → Saving to: ../data/clean\laliga\La Liga_2023-2024_misc.csv
# Cleaning file 52/106: ../data/raw\laliga\La Liga_2023-2024_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['France' 'Brazil' 'Morocco' 'Argentina' 'Spain']
# → Saving to: ../data/clean\laliga\La Liga_2023-2024_standard.csv
# Cleaning file 53/106: ../data/raw\laliga\La Liga_2024-2025_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['England' 'Spain' 'France' 'Morocco' 'Nigeria']
# → Saving to: ../data/clean\laliga\La Liga_2024-2025_misc.csv
# Cleaning file 54/106: ../data/raw\laliga\La Liga_2024-2025_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['England' 'Spain' 'France' 'Morocco' 'Nigeria']
# → Saving to: ../data/clean\laliga\La Liga_2024-2025_standard.csv
# Cleaning file 55/106: ../data/raw\ligue1\Ligue 1_2016-2017_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Morocco' 'Algeria' 'Ghana' nan 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2016-2017_misc.csv
# Cleaning file 56/106: ../data/raw\ligue1\Ligue 1_2016-2017_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Morocco' 'Algeria' 'Ghana' nan 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2016-2017_standard.csv
# Cleaning file 57/106: ../data/raw\ligue1\Ligue 1_2017-2018_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Tunisia' 'Algeria' nan 'France' 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2017-2018_misc.csv
# Cleaning file 58/106: ../data/raw\ligue1\Ligue 1_2017-2018_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Tunisia' 'Algeria' nan 'France' 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2017-2018_standard.csv
# Cleaning file 59/106: ../data/raw\ligue1\Ligue 1_2018-2019_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['France' 'Morocco' 'Algeria' nan 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2018-2019_misc.csv
# Cleaning file 60/106: ../data/raw\ligue1\Ligue 1_2018-2019_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['France' 'Morocco' 'Algeria' nan 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2018-2019_standard.csv
# Cleaning file 61/106: ../data/raw\ligue1\Ligue 1_2019-2020_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Morocco' 'Algeria' 'France' 'Ivory Coast' nan]
# → Saving to: ../data/clean\ligue1\Ligue 1_2019-2020_misc.csv
# Cleaning file 62/106: ../data/raw\ligue1\Ligue 1_2019-2020_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Morocco' 'Algeria' 'France' 'Ivory Coast' nan]
# → Saving to: ../data/clean\ligue1\Ligue 1_2019-2020_standard.csv
# Cleaning file 63/106: ../data/raw\ligue1\Ligue 1_2020-2021_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['France' 'Morocco' 'Algeria' 'Senegal' nan]
# → Saving to: ../data/clean\ligue1\Ligue 1_2020-2021_misc.csv
# Cleaning file 64/106: ../data/raw\ligue1\Ligue 1_2020-2021_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['France' 'Morocco' 'Algeria' 'Senegal' nan]
# → Saving to: ../data/clean\ligue1\Ligue 1_2020-2021_standard.csv
# Cleaning file 65/106: ../data/raw\ligue1\Ligue 1_2021-2022_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Morocco' 'Ghana' 'France' 'Bosnia and Herzegovina' 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2021-2022_misc.csv
# Cleaning file 66/106: ../data/raw\ligue1\Ligue 1_2021-2022_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Morocco' 'Ghana' 'France' 'Bosnia and Herzegovina' 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2021-2022_standard.csv
# Cleaning file 67/106: ../data/raw\ligue1\Ligue 1_2022-2023_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Morocco' 'Algeria' 'Ghana' 'France' 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2022-2023_misc.csv
# Cleaning file 68/106: ../data/raw\ligue1\Ligue 1_2022-2023_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Morocco' 'Algeria' 'Ghana' 'France' 'Ivory Coast']
# → Saving to: ../data/clean\ligue1\Ligue 1_2022-2023_standard.csv
# Cleaning file 69/106: ../data/raw\ligue1\Ligue 1_2023-2024_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['France' 'Morocco' 'Ghana' 'Nigeria' 'Brazil']
# → Saving to: ../data/clean\ligue1\Ligue 1_2023-2024_misc.csv
# Cleaning file 70/106: ../data/raw\ligue1\Ligue 1_2023-2024_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['France' 'Morocco' 'Ghana' 'Nigeria' 'Brazil']
# → Saving to: ../data/clean\ligue1\Ligue 1_2023-2024_standard.csv
# Cleaning file 71/106: ../data/raw\ligue1\Ligue 1_2024-2025_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['France' 'Morocco' 'Algeria' nan 'Tunisia']
# → Saving to: ../data/clean\ligue1\Ligue 1_2024-2025_misc.csv
# Cleaning file 72/106: ../data/raw\ligue1\Ligue 1_2024-2025_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['France' 'Morocco' 'Algeria' nan 'Tunisia']
# → Saving to: ../data/clean\ligue1\Ligue 1_2024-2025_standard.csv
# Cleaning file 73/106: ../data/raw\seriea\Serie A_2016-2017_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Italy' 'Ghana' nan 'Brazil' 'Albania']
# → Saving to: ../data/clean\seriea\Serie A_2016-2017_misc.csv
# Cleaning file 74/106: ../data/raw\seriea\Serie A_2016-2017_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Italy' 'Ghana' nan 'Brazil' 'Albania']
# → Saving to: ../data/clean\seriea\Serie A_2016-2017_standard.csv
# Cleaning file 75/106: ../data/raw\seriea\Serie A_2017-2018_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['England' 'Italy' 'Ghana' nan 'Albania']
# → Saving to: ../data/clean\seriea\Serie A_2017-2018_misc.csv
# Cleaning file 76/106: ../data/raw\seriea\Serie A_2017-2018_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['England' 'Italy' 'Ghana' nan 'Albania']
# → Saving to: ../data/clean\seriea\Serie A_2017-2018_standard.csv
# Cleaning file 77/106: ../data/raw\seriea\Serie A_2018-2019_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Italy' 'Ghana' nan 'Nigeria' 'Spain']
# → Saving to: ../data/clean\seriea\Serie A_2018-2019_misc.csv
# Cleaning file 78/106: ../data/raw\seriea\Serie A_2018-2019_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Italy' 'Ghana' nan 'Nigeria' 'Spain']
# → Saving to: ../data/clean\seriea\Serie A_2018-2019_standard.csv
# Cleaning file 79/106: ../data/raw\seriea\Serie A_2019-2020_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Italy' 'Netherlands' 'France' 'Colombia' 'Ghana']
# → Saving to: ../data/clean\seriea\Serie A_2019-2020_misc.csv
# Cleaning file 80/106: ../data/raw\seriea\Serie A_2019-2020_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Italy' 'Netherlands' 'France' 'Colombia' 'Ghana']
# → Saving to: ../data/clean\seriea\Serie A_2019-2020_standard.csv
# Cleaning file 81/106: ../data/raw\seriea\Serie A_2020-2021_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Italy' 'France' 'Colombia' 'Ivory Coast' 'Spain']
# → Saving to: ../data/clean\seriea\Serie A_2020-2021_misc.csv
# Cleaning file 82/106: ../data/raw\seriea\Serie A_2020-2021_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Italy' 'France' 'Colombia' 'Ivory Coast' 'Spain']
# → Saving to: ../data/clean\seriea\Serie A_2020-2021_standard.csv
# Cleaning file 83/106: ../data/raw\seriea\Serie A_2021-2022_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['England' 'Italy' 'Switzerland' 'Ghana' 'Colombia']
# → Saving to: ../data/clean\seriea\Serie A_2021-2022_misc.csv
# Cleaning file 84/106: ../data/raw\seriea\Serie A_2021-2022_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['England' 'Italy' 'Switzerland' 'Ghana' 'Colombia']
# → Saving to: ../data/clean\seriea\Serie A_2021-2022_standard.csv
# Cleaning file 85/106: ../data/raw\seriea\Serie A_2022-2023_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Republic of Ireland' 'Denmark' 'England' 'Italy' 'France']
# → Saving to: ../data/clean\seriea\Serie A_2022-2023_misc.csv
# Cleaning file 86/106: ../data/raw\seriea\Serie A_2022-2023_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Republic of Ireland' 'Denmark' 'England' 'Italy' 'France']
# → Saving to: ../data/clean\seriea\Serie A_2022-2023_standard.csv
# Cleaning file 87/106: ../data/raw\seriea\Serie A_2023-2024_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['England' 'Italy' 'France' 'Switzerland' 'Nigeria']
# → Saving to: ../data/clean\seriea\Serie A_2023-2024_misc.csv
# Cleaning file 88/106: ../data/raw\seriea\Serie A_2023-2024_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['England' 'Italy' 'France' 'Switzerland' 'Nigeria']
# → Saving to: ../data/clean\seriea\Serie A_2023-2024_standard.csv
# Cleaning file 89/106: ../data/raw\seriea\Serie A_2024-2025_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Republic of Ireland' nan 'Denmark' 'England' 'Italy']
# → Saving to: ../data/clean\seriea\Serie A_2024-2025_misc.csv
# Cleaning file 90/106: ../data/raw\seriea\Serie A_2024-2025_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Republic of Ireland' nan 'Denmark' 'England' 'Italy']
# → Saving to: ../data/clean\seriea\Serie A_2024-2025_standard.csv
# Cleaning file 91/106: ../data/raw\ucl\Champions League_2016-2017_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: [nan 'Cameroon' 'England' 'Brazil' 'Argentina']
# → Saving to: ../data/clean\ucl\Champions League_2016-2017_misc.csv
# Cleaning file 92/106: ../data/raw\ucl\Champions League_2016-2017_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: [nan 'Cameroon' 'England' 'Brazil' 'Argentina']
# → Saving to: ../data/clean\ucl\Champions League_2016-2017_standard.csv
# Cleaning file 93/106: ../data/raw\ucl\Champions League_2017-2018_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Cameroon' 'Argentina' 'England' 'Brazil' 'Albania']
# → Saving to: ../data/clean\ucl\Champions League_2017-2018_misc.csv
# Cleaning file 94/106: ../data/raw\ucl\Champions League_2017-2018_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Cameroon' 'Argentina' 'England' 'Brazil' 'Albania']
# → Saving to: ../data/clean\ucl\Champions League_2017-2018_standard.csv
# Cleaning file 95/106: ../data/raw\ucl\Champions League_2018-2019_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Cameroon' 'Switzerland' 'Argentina' 'Ivory Coast' 'Morocco']
# → Saving to: ../data/clean\ucl\Champions League_2018-2019_misc.csv
# Cleaning file 96/106: ../data/raw\ucl\Champions League_2018-2019_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Cameroon' 'Switzerland' 'Argentina' 'Ivory Coast' 'Morocco']
# → Saving to: ../data/clean\ucl\Champions League_2018-2019_standard.csv
# Cleaning file 97/106: ../data/raw\ucl\Champions League_2019-2020_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['England' 'United States' 'North Macedonia' 'Spain' 'Argentina']
# → Saving to: ../data/clean\ucl\Champions League_2019-2020_misc.csv
# Cleaning file 98/106: ../data/raw\ucl\Champions League_2019-2020_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['England' 'United States' 'North Macedonia' 'Spain' 'Argentina']
# → Saving to: ../data/clean\ucl\Champions League_2019-2020_standard.csv
# Cleaning file 99/106: ../data/raw\ucl\Champions League_2020-2021_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Senegal' 'England' 'Italy' 'Argentina' 'United States']
# → Saving to: ../data/clean\ucl\Champions League_2020-2021_misc.csv
# Cleaning file 100/106: ../data/raw\ucl\Champions League_2020-2021_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Senegal' 'England' 'Italy' 'Argentina' 'United States']
# → Saving to: ../data/clean\ucl\Champions League_2020-2021_standard.csv
# Cleaning file 101/106: ../data/raw\ucl\Champions League_2021-2022_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['United States' 'Ghana' 'Argentina' 'Austria' 'Spain']
# → Saving to: ../data/clean\ucl\Champions League_2021-2022_misc.csv
# Cleaning file 102/106: ../data/raw\ucl\Champions League_2021-2022_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['United States' 'Ghana' 'Argentina' 'Austria' 'Spain']
# → Saving to: ../data/clean\ucl\Champions League_2021-2022_standard.csv
# Cleaning file 103/106: ../data/raw\ucl\Champions League_2022-2023_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Israel' 'Denmark' 'Italy' 'Argentina' 'Austria']
# → Saving to: ../data/clean\ucl\Champions League_2022-2023_misc.csv
# Cleaning file 104/106: ../data/raw\ucl\Champions League_2022-2023_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Israel' 'Denmark' 'Italy' 'Argentina' 'Austria']
# → Saving to: ../data/clean\ucl\Champions League_2022-2023_standard.csv
# Cleaning file 105/106: ../data/raw\ucl\Champions League_2023-2024_misc.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'fouls_drawn', 'offsides', 'pkwon', 'country_code']
# → Sample nationality values: ['Netherlands' 'United States' 'Ghana' 'Italy' 'Tunisia']
# → Saving to: ../data/clean\ucl\Champions League_2023-2024_misc.csv
# Cleaning file 106/106: ../data/raw\ucl\Champions League_2023-2024_standard.csv
# → Columns after cleaning: ['player', 'nationality', 'position', 'team', 'age', 'birth_year', 'matches_played', 'starts', 'minutes', 'goals', 'assists', 'goals_and_assists', 'non_penalty_goals', 'pens_scored', 'pens_attempted', 'xg_expected_goals', 'npxg_non_penalty_xg', 'xag_expected_assisted_goals', 'npxg+xag', 'progressive_carries', 'prgp', 'goals_per90', 'assists_per90', 'goals_and_assists_per90', 'non_penalty_goals_per90', 'non_penalty_goals_and_assists', 'country_code']
# → Sample nationality values: ['Netherlands' 'United States' 'Ghana' 'Italy' 'Tunisia']
# → Saving to: ../data/clean\ucl\Champions League_2023-2024_standard.csv
# ✅ All files cleaned and saved into the clean/ folder!

# %%
# drop duplicate columns based on suffix
# fix nationality column
# rename goals + assists per 90 columns
#reorder columns
#new_order = ['player', 'age', 'team', 'position', 'minutes', 'nationality_clean', 'goals', 'assists']
#df = df[new_order]
#or
#priority_cols = ['player', 'team', 'nationality_clean']
#df = df[priority_cols + [col for col in df.columns if col not in priority_cols]]

# change age and year data types
#big5_standard_misc.

# Step 2: Define the rename map
#rename_map_post_merge = {
  
#}
